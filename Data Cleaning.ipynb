# %% [markdown]
# # Bank Marketing Data Cleaning

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("DSA Data Set.csv")

# %%
data['y'] = data.y.map({'no':0,'yes':1}) #dependent variable

# %%
data['marital'] = data.marital.map({'divorced':0,'unknown':0,'single':0,'married':1}) #couple = 1 | alone = 0

# %%
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid        1     basic.4y       no      no   no  telephone
# 1   57   services        1  high.school  unknown      no   no  telephone
# 2   37   services        1  high.school       no     yes   no  telephone
# 3   40     admin.        1     basic.6y       no      no   no  telephone
# 4   56   services        1  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon  ...    999         0  nonexistent           1.1
# 1   may         mon  ...    999         0  nonexistent           1.1
# 2   may         mon  ...    999         0  nonexistent           1.1
# 3   may         mon  ...    999         0  nonexistent           1.1
# 4   may         mon  ...    999         0  nonexistent           1.1
#
#   cons.price.idx  cons.conf.idx  euribor3m  nr.employed  ModelPrediction  y
# ...

# %%
data.loc[data['age'] <= 21, 'age'] = 0 #teens
data.loc[(data['age'] > 21) & (data['age'] <= 30), 'age'] = 1 #young adults
data.loc[(data['age'] > 30) & (data['age'] <= 50), 'age'] = 2 #adults
data.loc[(data['age'] > 50) & (data['age'] <= 65), 'age'] = 3 #old adults
data.loc[data['age'] > 65, 'age'] = 4 #senior citizens

# %%
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0    3  housemaid        1     basic.4y       no      no   no  telephone
# 1    3   services        1  high.school  unknown      no   no  telephone
# 2    2   services        1  high.school       no     yes   no  telephone
# 3    2     admin.        1     basic.6y       no      no   no  telephone
# 4    3   services        1  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon  ...    999         0  nonexistent           1.1
# 1   may         mon  ...    999         0  nonexistent           1.1
# 2   may         mon  ...    999         0  nonexistent           1.1
# 3   may         mon  ...    999         0  nonexistent           1.1
# 4   may         mon  ...    999         0  nonexistent           1.1
#
#   cons.price.idx  cons.conf.idx  euribor3m  nr.employed  ModelPrediction  y
# ...

# %%
print(data['age'].max())
print(data['age'].min())
# Out:
# 4
# 0

# %%
#WC(admin,mgmt) = 0 | BC(bc, housemaid,services,technicians) = 1 | owners(self,entr) = 2 | no jobs(retired, unemp, unk) = 3 | students = 4
data['job'] = data.job.map({'admin.':0,'management':0,'housemaid':1,'services':1,'blue-collar':1,'technician':1,'self-employed':2,'entrepreneur':2,'retired':3,'unemployed':3,'unknown':3,'student':4})

# %%
data.head()
# Out:
#    age  job  marital    education  default housing loan    contact month  \
# 0    3    1        1     basic.4y       no      no   no  telephone   may
# 1    3    1        1  high.school  unknown      no   no  telephone   may
# 2    2    1        1  high.school       no     yes   no  telephone   may
# 3    2    0        1     basic.6y       no      no   no  telephone   may
# 4    3    1        1  high.school       no      no  yes  telephone   may
#
#   day_of_week  ...  pdays  previous     poutcome  emp.var.rate cons.price.idx  \
# 0         mon  ...    999         0  nonexistent           1.1         93.994
# 1         mon  ...    999         0  nonexistent           1.1         93.994
# 2         mon  ...    999         0  nonexistent           1.1         93.994
# 3         mon  ...    999         0  nonexistent           1.1         93.994
# 4         mon  ...    999         0  nonexistent           1.1         93.994
#
# ...

# %%
data['default'] = data.default.map({'no':0,'unknown':0,'yes':1})

# %%
data['housing'] = data.housing.map({'no':0,'unknown':0,'yes':1})

# %%
data['loan'] = data.loan.map({'no':0,'unknown':0,'yes':1})

# %%
data['contact'] = data.contact.map({'telephone':0,'cellular':1})

# %%
#previously contacted or not | 0 = 0 | rest = 1

# %%
data.loc[data['previous'] == 0, 'previous'] = 0

# %%
data.loc[data['previous'] > 0, 'previous'] = 1

# %%
data.head()
# Out:
#    age  job  marital    education  default  housing  loan  contact month  \
# 0    3    1        1     basic.4y        0        0     0        0   may
# 1    3    1        1  high.school        0        0     0        0   may
# 2    2    1        1  high.school        0        1     0        0   may
# 3    2    0        1     basic.6y        0        0     0        0   may
# 4    3    1        1  high.school        0        0     1        0   may
#
#   day_of_week  ...  pdays  previous     poutcome  emp.var.rate cons.price.idx  \
# 0         mon  ...    999         0  nonexistent           1.1         93.994
# 1         mon  ...    999         0  nonexistent           1.1         93.994
# 2         mon  ...    999         0  nonexistent           1.1         93.994
# 3         mon  ...    999         0  nonexistent           1.1         93.994
# 4         mon  ...    999         0  nonexistent           1.1         93.994
#
# ...

# %%
print(data['previous'].max())
print(data['previous'].min())
# Out:
# 1
# 0

# %%
data = data.drop(['duration'], axis = 1)

# %%
data.head()
# Out:
#    age  job  marital    education  default  housing  loan  contact month  \
# 0    3    1        1     basic.4y        0        0     0        0   may
# 1    3    1        1  high.school        0        0     0        0   may
# 2    2    1        1  high.school        0        1     0        0   may
# 3    2    0        1     basic.6y        0        0     0        0   may
# 4    3    1        1  high.school        0        0     1        0   may
#
#   day_of_week  ...  pdays  previous     poutcome emp.var.rate  cons.price.idx  \
# 0         mon  ...    999         0  nonexistent          1.1          93.994
# 1         mon  ...    999         0  nonexistent          1.1          93.994
# 2         mon  ...    999         0  nonexistent          1.1          93.994
# 3         mon  ...    999         0  nonexistent          1.1          93.994
# 4         mon  ...    999         0  nonexistent          1.1          93.994
#
# ...

# %%
#10 months, 2 months no data, divided into two groups of 5 | apr-aug = 0 | rest = 1
data['month'] = data.month.map({'mar':1,'sep':1,'oct':1,'nov':1,'dec':1,'apr':0,'may':0,'jun':0,'jul':0,'aug':0})

# %%
data['day_of_week'] = data.day_of_week.map({'mon':0,'tue':1,'wed':2,'thu':3,'fri':4})

# %%
data = data.drop(['ModelPrediction'], axis = 1)

# %%
data.head()
# Out:
#    age  job  marital    education  default  housing  loan  contact  month  \
# 0    3    1        1     basic.4y        0        0     0        0      0
# 1    3    1        1  high.school        0        0     0        0      0
# 2    2    1        1  high.school        0        1     0        0      0
# 3    2    0        1     basic.6y        0        0     0        0      0
# 4    3    1        1  high.school        0        0     1        0      0
#
#    day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0            0         1    999         0  nonexistent           1.1
# 1            0         1    999         0  nonexistent           1.1
# 2            0         1    999         0  nonexistent           1.1
# 3            0         1    999         0  nonexistent           1.1
# 4            0         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# ...

# %%
#Basic(all basics)=0 | School(high,profess, uni) = 1 | No edu(illi, unkno) = 2
data['education'] = data.education.map({'basic.4y':0,'basic.6y':0,'basic.9y':0,'high.school':1,'professional.course':1,'university.degree':1,'unknown':2,'illiterate':2})

# %%
data.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0    3    1        1          0        0        0     0        0      0
# 1    3    1        1          1        0        0     0        0      0
# 2    2    1        1          1        0        1     0        0      0
# 3    2    0        1          0        0        0     0        0      0
# 4    3    1        1          1        0        0     1        0      0
#
#    day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0            0         1    999         0  nonexistent           1.1
# 1            0         1    999         0  nonexistent           1.1
# 2            0         1    999         0  nonexistent           1.1
# 3            0         1    999         0  nonexistent           1.1
# 4            0         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# ...

# %%
data = data.drop(['campaign'], axis = 1) #unknown

# %%
data.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0    3    1        1          0        0        0     0        0      0
# 1    3    1        1          1        0        0     0        0      0
# 2    2    1        1          1        0        1     0        0      0
# 3    2    0        1          0        0        0     0        0      0
# 4    3    1        1          1        0        0     1        0      0
#
#    day_of_week  pdays  previous     poutcome  emp.var.rate  cons.price.idx  \
# 0            0    999         0  nonexistent           1.1          93.994
# 1            0    999         0  nonexistent           1.1          93.994
# 2            0    999         0  nonexistent           1.1          93.994
# 3            0    999         0  nonexistent           1.1          93.994
# 4            0    999         0  nonexistent           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed  y
# ...

# %%
data = data.drop(['pdays'], axis = 1)

# %%
data['poutcome'] = data.poutcome.map({'nonexistent':0,'success':1,'failure':2})

# %%
data.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0    3    1        1          0        0        0     0        0      0
# 1    3    1        1          1        0        0     0        0      0
# 2    2    1        1          1        0        1     0        0      0
# 3    2    0        1          0        0        0     0        0      0
# 4    3    1        1          1        0        0     1        0      0
#
#    day_of_week  previous  poutcome  emp.var.rate  cons.price.idx  \
# 0            0         0         0           1.1          93.994
# 1            0         0         0           1.1          93.994
# 2            0         0         0           1.1          93.994
# 3            0         0         0           1.1          93.994
# 4            0         0         0           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed  y
# 0          -36.4      4.857       5191.0  0
# 1          -36.4      4.857       5191.0  0
# ...

# %%
data = data.drop(['emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'nr.employed'], axis = 1)

# %%
data.euribor3m=data.euribor3m.apply( lambda v: ((v-data.euribor3m.min())/(data.euribor3m.max()-data.euribor3m.min())))

# %%
data.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0    3    1        1          0        0        0     0        0      0
# 1    3    1        1          1        0        0     0        0      0
# 2    2    1        1          1        0        1     0        0      0
# 3    2    0        1          0        0        0     0        0      0
# 4    3    1        1          1        0        0     1        0      0
#
#    day_of_week  previous  poutcome  euribor3m  y
# 0            0         0         0   0.957379  0
# 1            0         0         0   0.957379  0
# 2            0         0         0   0.957379  0
# 3            0         0         0   0.957379  0
# 4            0         0         0   0.957379  0

# %%
data.to_csv('clean_data.csv')

# %%
features=['age','job','marital','education','default','housing','loan','contact','month','day_of_week','previous','poutcome','euribor3m']
target='y'
X = data.loc[:,features]
y = data.loc[:,target]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import scale
from sklearn.svm import SVC #Importing SVM(SVC) function
from sklearn.model_selection import StratifiedKFold

# %%
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.2, random_state=0)
lr.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-71e2b12406c1> in <module>
# ----> 1 X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.2, random_state=0)
#       2 lr.fit(X_train, y_train)
#
# NameError: name 'train_test_split' is not defined

# %%
cv = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)


model_svc = SVC(kernel='rbf',  class_weight='balanced')#Initalising SVM model with rbf kernel and balanced class weight
model_svc.fit(X_train, y_train)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
y_test = model_svc.predict(X_test)
accuracy_score(y_test,y_test_hat, normalize = True) * 100

# %%
print("Confusion Matrix")
print(confusion_matrix(y_test,y_test_hat))
print("")
print(classification_report(y_test,y_test_hat))
